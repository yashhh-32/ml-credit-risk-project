# %%
import pandas as pd
import numpy as np

# %%
df_customers = pd.read_csv('customers.csv')
print(df_customers.shape)
df_customers.head()
# Out:
# (50000, 12)
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#          state  zipcode
# 0        Delhi   110001
# 1   Tamil Nadu   600001
# 2  West Bengal   700001
# 3    Karnataka   560001
# 4  Maharashtra   411001

# %%
df_loans = pd.read_csv('loans.csv')
print(df_loans.shape)
df_loans.head()
# Out:
# (50000, 15)
#   loan_id cust_id loan_purpose  loan_type  sanction_amount  loan_amount  \
# 0  L00001  C00001         Auto    Secured          3004000      2467000
# 1  L00002  C00002         Home    Secured          4161000      3883000
# 2  L00003  C00003     Personal  Unsecured          2401000      2170000
# 3  L00004  C00004     Personal  Unsecured          2345000      1747000
# 4  L00005  C00005         Auto    Secured          4647000      4520000
#
#    processing_fee     gst  net_disbursement  loan_tenure_months  \
# 0         49340.0  444060           1973600                  33
# 1         77660.0  698940           3106400                  30
# 2         43400.0  390600           1736000                  21
# 3         34940.0  314460           1397600                   6
# 4         90400.0  813600           3616000                  28
#
#    principal_outstanding  bank_balance_at_application disbursal_date  \
# 0                1630408                       873386     2019-07-24
# 1                 709309                       464100     2019-07-24
# 2                1562399                      1476042     2019-07-24
# 3                1257839                      1031094     2019-07-24
# 4                1772334                      1032458     2019-07-24
#
#   installment_start_dt  default
# 0           2019-08-10    False
# 1           2019-08-15    False
# 2           2019-08-21    False
# 3           2019-08-09    False
# 4           2019-08-02    False

# %%
df_bureau = pd.read_csv("bureau_data.csv")
print(df_bureau.shape)
df_bureau.head()
# Out:
# (50000, 8)
#   cust_id  number_of_open_accounts  number_of_closed_accounts  \
# 0  C00001                        1                          1
# 1  C00002                        3                          1
# 2  C00003                        2                          1
# 3  C00004                        3                          0
# 4  C00005                        4                          2
#
#    total_loan_months  delinquent_months  total_dpd  enquiry_count  \
# 0                 42                  0          0              3
# 1                 96                 12         60              5
# 2                 82                 24        147              6
# 3                115                 15         87              5
# 4                120                  0          0              5
#
#    credit_utilization_ratio
# 0                         7
# 1                         4
# 2                        58
# 3                        26
# 4                        10

# %%
df = pd.merge(df_customers,df_loans,on = 'cust_id')

# %%
df = pd.merge(df,df_bureau,on = 'cust_id')

# %%
df.head()
# Out:
#   cust_id  age gender marital_status employment_status   income  \
# 0  C00001   44      M        Married     Self-Employed  2586000
# 1  C00002   38      M        Married          Salaried  1206000
# 2  C00003   46      F        Married     Self-Employed  2878000
# 3  C00004   55      F         Single     Self-Employed  3547000
# 4  C00005   37      M        Married          Salaried  3432000
#
#    number_of_dependants residence_type  years_at_current_address       city  \
# 0                     3          Owned                        27      Delhi
# 1                     3          Owned                         4    Chennai
# 2                     3          Owned                        24    Kolkata
# 3                     1          Owned                        15  Bangalore
# 4                     3          Owned                        28       Pune
#
#    ... disbursal_date  installment_start_dt default number_of_open_accounts  \
# 0  ...     2019-07-24            2019-08-10   False                       1
# 1  ...     2019-07-24            2019-08-15   False                       3
# 2  ...     2019-07-24            2019-08-21   False                       2
# 3  ...     2019-07-24            2019-08-09   False                       3
# 4  ...     2019-07-24            2019-08-02   False                       4
#
#   number_of_closed_accounts  total_loan_months  delinquent_months  total_dpd  \
# 0                         1                 42                  0          0
# 1                         1                 96                 12         60
# 2                         1                 82                 24        147
# 3                         0                115                 15         87
# 4                         2                120                  0          0
#
#    enquiry_count  credit_utilization_ratio
# 0              3                         7
# 1              5                         4
# 2              6                        58
# 3              5                        26
# 4              5                        10
#
# [5 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      50000 non-null  object
#  1   age                          50000 non-null  int64
#  2   gender                       50000 non-null  object
#  3   marital_status               50000 non-null  object
#  4   employment_status            50000 non-null  object
#  5   income                       50000 non-null  int64
#  6   number_of_dependants         50000 non-null  int64
#  7   residence_type               49938 non-null  object
#  8   years_at_current_address     50000 non-null  int64
#  9   city                         50000 non-null  object
#  10  state                        50000 non-null  object
#  11  zipcode                      50000 non-null  int64
#  12  loan_id                      50000 non-null  object
#  13  loan_purpose                 50000 non-null  object
#  14  loan_type                    50000 non-null  object
#  15  sanction_amount              50000 non-null  int64
#  16  loan_amount                  50000 non-null  int64
#  17  processing_fee               50000 non-null  float64
#  18  gst                          50000 non-null  int64
#  19  net_disbursement             50000 non-null  int64
#  20  loan_tenure_months           50000 non-null  int64
#  21  principal_outstanding        50000 non-null  int64
#  22  bank_balance_at_application  50000 non-null  int64
#  23  disbursal_date               50000 non-null  object
#  24  installment_start_dt         50000 non-null  object
#  25  default                      50000 non-null  bool
#  26  number_of_open_accounts      50000 non-null  int64
#  27  number_of_closed_accounts    50000 non-null  int64
#  28  total_loan_months            50000 non-null  int64
#  29  delinquent_months            50000 non-null  int64
#  30  total_dpd                    50000 non-null  int64
#  31  enquiry_count                50000 non-null  int64
#  32  credit_utilization_ratio     50000 non-null  int64
# dtypes: bool(1), float64(1), int64(19), object(12)
# memory usage: 12.3+ MB

# %% [markdown]
# ## Data Cleaning

# %%
df['default'] = df['default'].astype(int)

# %%
from sklearn.model_selection import train_test_split
import seaborn as sns
from matplotlib import pyplot as plt

# %%
X = df.drop(columns = ['default'])
y = df['default']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
df_train = pd.concat([X_train,y_train],axis = 1)
df_test = pd.concat([X_test,y_test],axis = 1)

# %%
df_train.shape
# Out:
# (37500, 33)

# %%
df_train.isna().sum()
# Out:
# cust_id                         0
# age                             0
# gender                          0
# marital_status                  0
# employment_status               0
# income                          0
# number_of_dependants            0
# residence_type                 48
# years_at_current_address        0
# city                            0
# state                           0
# zipcode                         0
# loan_id                         0
# loan_purpose                    0
# loan_type                       0
# sanction_amount                 0
# loan_amount                     0
# processing_fee                  0
# gst                             0
# net_disbursement                0
# loan_tenure_months              0
# principal_outstanding           0
# bank_balance_at_application     0
# disbursal_date                  0
# installment_start_dt            0
# number_of_open_accounts         0
# number_of_closed_accounts       0
# total_loan_months               0
# delinquent_months               0
# total_dpd                       0
# enquiry_count                   0
# credit_utilization_ratio        0
# default                         0
# dtype: int64

# %%
residence_type_mode= df_train['residence_type'].mode()[0]

# %%
df_train.fillna(residence_type_mode,inplace = True)
df_test.residence_type.fillna(residence_type_mode, inplace=True)
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_27652\1100403499.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_test.residence_type.fillna(residence_type_mode, inplace=True)

# %%
numerical_columns = ['age', 'income', 'number_of_dependants', 'years_at_current_address', 
                      'sanction_amount', 'loan_amount', 'processing_fee', 'gst', 'net_disbursement', 
                      'loan_tenure_months','principal_outstanding', 'bank_balance_at_application',
                      'number_of_open_accounts','number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
                       'total_dpd', 'enquiry_count', 'credit_utilization_ratio']

categorical_columns =  ['gender', 'marital_status', 'employment_status', 'residence_type', 'city', 
                       'state', 'zipcode', 'loan_purpose', 'loan_type', 'default']

# %%
# number of numerical columns
n = len(numerical_columns)

# create subplots (adjust rows & cols as per need)
rows = (n + 2) // 3   # 3 plots per row
cols = 3

fig, axes = plt.subplots(rows, cols, figsize=(15, 5*rows))
axes = axes.flatten()

for i, col in enumerate(numerical_columns):
    sns.boxplot(x=df_train[col], ax=axes[i])
    axes[i].set_title(col)

# remove any empty subplots
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
# number of numerical columns
n = len(numerical_columns)

# create subplots (adjust rows & cols as per need)
rows = (n + 2) // 3   # 3 plots per row
cols = 3

fig, axes = plt.subplots(rows, cols, figsize=(15, 5*rows))
axes = axes.flatten()

for i, col in enumerate(numerical_columns):
    sns.histplot(x=df_train[col], ax=axes[i], kde=True)  # <-- changed y= to x=
    axes[i].set_title(col)

# remove any empty subplots
for j in range(i+1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df_train['processing_fee'].describe()
# Out:
# count     37500.00
# mean      80724.11
# std      120830.65
# min           0.00
# 25%       19180.00
# 50%       44700.00
# 75%       92000.00
# max     5698029.90
# Name: processing_fee, dtype: float64

# %%
df_train[(df_train['processing_fee']/df_train['loan_amount']) > 0.03][['processing_fee','loan_amount']]
# Out:
#        processing_fee  loan_amount
# 23981      2669791.02      2234000
# 9898       5293543.52      3626000
# 47089      1858964.77      1738000
# 33705      5678020.86      3812000
# 12294      5698029.90      4639000
# 28174      1214492.67       966000
# 29305      3036378.01      2616000

# %%
df_train_1 = df_train[df_train.processing_fee/df_train.loan_amount<0.03].copy()

# %%
df_test = df_test[df_test.processing_fee/df_test.loan_amount<0.03].copy()
df_test.shape
# Out:
# (12498, 33)

# %%
# Use other business rules for data validation
# Rule 1: GST should not be more than 20%

df_train_1[df_train_1.gst/df_train_1.loan_amount>0.2]
# Out:
# Empty DataFrame
# Columns: [cust_id, age, gender, marital_status, employment_status, income, number_of_dependants, residence_type, years_at_current_address, city, state, zipcode, loan_id, loan_purpose, loan_type, sanction_amount, loan_amount, processing_fee, gst, net_disbursement, loan_tenure_months, principal_outstanding, bank_balance_at_application, disbursal_date, installment_start_dt, number_of_open_accounts, number_of_closed_accounts, total_loan_months, delinquent_months, total_dpd, enquiry_count, credit_utilization_ratio, default]
# Index: []
#
# [0 rows x 33 columns]

# %%
for col in categorical_columns:
    print(f"{col} == {df_train_1[col].unique()}")
# Out:
# gender == ['F' 'M']
# marital_status == ['Single' 'Married']
# employment_status == ['Salaried' 'Self-Employed']
# residence_type == ['Owned' 'Mortgage' 'Rented']
# city == ['Ahmedabad' 'Delhi' 'Lucknow' 'Bangalore' 'Jaipur' 'Hyderabad' 'Kolkata'
#  'Pune' 'Chennai' 'Mumbai']
# state == ['Gujarat' 'Delhi' 'Uttar Pradesh' 'Karnataka' 'Rajasthan' 'Telangana'
#  'West Bengal' 'Maharashtra' 'Tamil Nadu']
# zipcode == [380001 110001 226001 560001 302001 500001 700001 411001 600001 400001]
# loan_purpose == ['Home' 'Auto' 'Personal' 'Education' 'Personaal']
# loan_type == ['Secured' 'Unsecured']
# default == [0 1]

# %%
df_train_1['loan_purpose']=df_train_1['loan_purpose'].replace('Personaal','Personal')
df_test['loan_purpose'] = df_test['loan_purpose'].replace('Personaal','Personal')

# %% [markdown]
# ## exploratory data analysis

# %%
plt.figure(figsize = (24,20))
for i,cols in enumerate(numerical_columns):
    plt.subplot(6,4,i+1)
    sns.kdeplot(df_train_1[cols][df_train_1['default']==1],fill =True, label = 'default =1')
    sns.kdeplot(df_train_1[cols][df_train_1['default'] == 0],fill = True,label = 'default = 0')
    plt.legend()
    plt.title(cols)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Feature Engineering

# %%
#loan to income ratio
df_train_1['loan_to_income'] = round(df_train_1['loan_amount']/df_train_1['income'],2)
#loan to income ratio
df_test['loan_to_income'] = round(df_test['loan_amount']/df_test['income'],2)

# %%
plt.figure(figsize = (10,5))
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default']==1],fill = True,label = 'default == 1')
sns.kdeplot(df_train_1['loan_to_income'][df_train_1['default']==0],fill = True,label = 'default == 0')
plt.legend()
plt.show()

# %% [markdown]
# #### defaulter tends to have high lti ratio

# %%
df_train_1['dilenquency_ratio'] = round(df_train_1['delinquent_months']/df_train_1['total_loan_months'],2)
df_test['dilenquency_ratio'] = round(df_test['delinquent_months']/df_test['total_loan_months'],2)

# %%
plt.figure(figsize = (10,5))
sns.kdeplot(df_train_1['dilenquency_ratio'][df_train_1['default']==1],fill = True,label = 'default == 1')
sns.kdeplot(df_train_1['dilenquency_ratio'][df_train_1['default']==0],fill = True,label = 'default == 0')
plt.legend()
plt.show()

# %%
df_train_1['avg_dpd_per_delinquency'] = np.where(
    df_train_1['delinquent_months'] != 0,
    (df_train_1['total_dpd'] / df_train_1['delinquent_months']).round(1),
    0
)

df_test['avg_dpd_per_delinquency'] = np.where(
    df_test['delinquent_months'] != 0,
    (df_test['total_dpd'] / df_test['delinquent_months']).round(1),
    0
)

# %%
plt.figure(figsize=(8, 4))
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 0], fill=True, label='default=0')
sns.kdeplot(df_train_1['avg_dpd_per_delinquency'][df_train_1['default'] == 1], fill=True, label='default=1')
plt.title(f"Avg DPD Per Delinquency Ratio KDE Plot with Hue by default")
plt.legend()
plt.show()

# %%
df_train_2 = df_train_1.drop(['cust_id', 'loan_id'],axis="columns")
df_test = df_test.drop(['cust_id', 'loan_id'],axis="columns")

# %%
df_train_3 = df_train_2.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_test = df_test.drop(['disbursal_date', 'installment_start_dt', 'loan_amount', 'income', 
                              'total_loan_months', 'delinquent_months', 'total_dpd'], axis="columns")
df_train_3.columns
# Out:
# Index(['age', 'gender', 'marital_status', 'employment_status',
#        'number_of_dependants', 'residence_type', 'years_at_current_address',
#        'city', 'state', 'zipcode', 'loan_purpose', 'loan_type',
#        'sanction_amount', 'processing_fee', 'gst', 'net_disbursement',
#        'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'default', 'loan_to_income',
#        'dilenquency_ratio', 'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
X_train.select_dtypes(['int64','float64']).columns
# Out:
# Index(['age', 'income', 'number_of_dependants', 'years_at_current_address',
#        'zipcode', 'sanction_amount', 'loan_amount', 'processing_fee', 'gst',
#        'net_disbursement', 'loan_tenure_months', 'principal_outstanding',
#        'bank_balance_at_application', 'number_of_open_accounts',
#        'number_of_closed_accounts', 'total_loan_months', 'delinquent_months',
#        'total_dpd', 'enquiry_count', 'credit_utilization_ratio'],
#       dtype='object')

# %%
X_train = df_train_3.drop(columns = 'default')
y_train = df_train_3['default']
from sklearn.preprocessing import MinMaxScaler

cols_to_scale = X_train.select_dtypes(['int64','float64']).columns
scaler = MinMaxScaler()
X_train[cols_to_scale] = scaler.fit_transform(X_train[cols_to_scale])
X_train.head()
# Out:
#        age gender marital_status employment_status  number_of_dependants  \
# 27434 0.52      F         Single          Salaried                  0.00
# 13400 0.21      M         Single          Salaried                  0.00
# 883   0.62      F         Single     Self-Employed                  0.00
# 7303  0.48      F         Single     Self-Employed                  0.20
# 45124 0.25      F         Single          Salaried                  0.00
#
#       residence_type  years_at_current_address       city          state  \
# 27434          Owned                      0.13  Ahmedabad        Gujarat
# 13400          Owned                      0.80      Delhi          Delhi
# 883         Mortgage                      0.93    Lucknow  Uttar Pradesh
# 7303           Owned                      0.87  Bangalore      Karnataka
# 45124          Owned                      0.87     Jaipur      Rajasthan
#
#        zipcode  ... loan_tenure_months principal_outstanding  \
# 27434     0.46  ...               0.34                  0.18
# 13400     0.00  ...               0.51                  0.20
# 883       0.20  ...               0.25                  0.27
# 7303      0.76  ...               0.28                  0.03
# 45124     0.33  ...               0.74                  0.01
#
#        bank_balance_at_application  number_of_open_accounts  \
# 27434                         0.07                     1.00
# 13400                         0.12                     0.67
# 883                           0.10                     0.33
# 7303                          0.01                     0.00
# 45124                         0.01                     0.33
#
#        number_of_closed_accounts  enquiry_count  credit_utilization_ratio  \
# 27434                       1.00           0.88                      0.60
# 13400                       0.50           0.38                      0.93
# 883                         0.50           0.38                      0.84
# 7303                        0.50           0.50                      0.34
# 45124                       0.00           0.50                      0.19
#
#        loan_to_income  dilenquency_ratio  avg_dpd_per_delinquency
# 27434            0.61               0.07                     0.55
# 13400            0.18               0.03                     0.42
# 883              0.08               0.17                     0.56
# 7303             0.19               0.00                     0.00
# 45124            0.36               0.10                     0.47
#
# [5 rows x 26 columns]

# %%
X_test = df_test.drop('default', axis='columns')
y_test = df_test['default']

X_test[cols_to_scale] = scaler.transform(X_test[cols_to_scale])
X_test.describe()
# Out:
#            age  number_of_dependants  years_at_current_address  zipcode  \
# count 12498.00              12498.00                  12498.00 12498.00
# mean      0.41                  0.39                      0.50     0.53
# std       0.19                  0.31                      0.30     0.29
# min       0.00                  0.00                      0.00     0.00
# 25%       0.29                  0.00                      0.23     0.33
# 50%       0.42                  0.40                      0.50     0.51
# 75%       0.54                  0.60                      0.77     0.76
# max       1.00                  1.00                      1.00     1.00
#
#        sanction_amount  processing_fee      gst  net_disbursement  \
# count         12498.00        12498.00 12498.00          12498.00
# mean              0.09            0.08     0.08              0.08
# std               0.12            0.11     0.11              0.11
# min               0.00            0.00     0.00              0.00
# 25%               0.02            0.02     0.02              0.02
# 50%               0.05            0.05     0.05              0.05
# 75%               0.10            0.10     0.10              0.10
# max               0.95            1.00     1.00              1.00
#
#        loan_tenure_months  principal_outstanding  bank_balance_at_application  \
# count            12498.00               12498.00                     12498.00
# mean                 0.38                   0.26                         0.12
# std                  0.24                   0.25                         0.13
# min                  0.00                  -0.00                         0.00
# 25%                  0.19                   0.08                         0.03
# 50%                  0.36                   0.20                         0.08
# 75%                  0.55                   0.35                         0.16
# max                  1.00                   1.00                         0.88
#
#        number_of_open_accounts  number_of_closed_accounts  enquiry_count  \
# count                 12498.00                   12498.00       12498.00
# mean                      0.50                       0.51           0.50
# std                       0.37                       0.41           0.26
# min                       0.00                       0.00           0.00
# 25%                       0.00                       0.00           0.38
# 50%                       0.67                       0.50           0.50
# 75%                       1.00                       1.00           0.75
# max                       1.00                       1.00           1.00
#
#        credit_utilization_ratio  loan_to_income  dilenquency_ratio  \
# count                  12498.00        12498.00           12498.00
# mean                       0.44            0.29               0.10
# std                        0.30            0.23               0.17
# min                        0.00            0.00               0.00
# 25%                        0.18            0.11               0.00
# 50%                        0.39            0.20               0.04
# 75%                        0.68            0.50               0.13
# max                        1.00            1.00               1.00
#
#        avg_dpd_per_delinquency
# count                 12498.00
# mean                      0.33
# std                       0.29
# min                       0.00
# 25%                       0.00
# 50%                       0.43
# 75%                       0.58
# max                       1.00

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Yash\AppData\Local\Programs\Python\Python310\python.exe

# %%
import sys
# !{sys.executable} -m pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\yash\appdata\local\programs\python\python310\lib\site-packages (0.14.5)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\yash\appdata\roaming\python\python310\site-packages (from statsmodels) (2.2.6)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\yash\appdata\roaming\python\python310\site-packages (from statsmodels) (1.15.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\yash\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (2.3.1)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\yash\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\yash\appdata\local\programs\python\python310\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\yash\appdata\local\programs\python\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yash\appdata\local\programs\python\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yash\appdata\local\programs\python\python310\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\yash\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calculate_vif(data):
    vif_df = pd.DataFrame()
    vif_df['Column'] = data.columns
    vif_df['VIF'] = [variance_inflation_factor(data.values,i) for i in range(data.shape[1])]
    return vif_df

# %%
calculate_vif(X_train[cols_to_scale])
# Out:
# C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                          Column    VIF
# 0                           age   5.72
# 1          number_of_dependants   2.73
# 2      years_at_current_address   3.42
# 3                       zipcode   3.79
# 4               sanction_amount 102.15
# 5                processing_fee    inf
# 6                           gst    inf
# 7              net_disbursement    inf
# 8            loan_tenure_months   6.14
# 9         principal_outstanding  16.28
# 10  bank_balance_at_application   9.28
# 11      number_of_open_accounts   4.35
# 12    number_of_closed_accounts   2.36
# 13                enquiry_count   6.40
# 14     credit_utilization_ratio   2.93
# 15               loan_to_income   6.92
# 16            dilenquency_ratio   1.95
# 17      avg_dpd_per_delinquency   2.93

# %%
features_to_drop_vif = ['sanction_amount', 'processing_fee', 'gst', 'net_disbursement','principal_outstanding']


X_train_1 = X_train.drop(features_to_drop_vif, axis='columns')
numeric_columns = X_train_1.select_dtypes(['int64', 'float64']).columns
numeric_columns
# Out:
# Index(['age', 'number_of_dependants', 'years_at_current_address', 'zipcode',
#        'loan_tenure_months', 'bank_balance_at_application',
#        'number_of_open_accounts', 'number_of_closed_accounts', 'enquiry_count',
#        'credit_utilization_ratio', 'loan_to_income', 'dilenquency_ratio',
#        'avg_dpd_per_delinquency'],
#       dtype='object')

# %%
calculate_vif(X_train_1[numeric_columns])
# Out:
#                          Column  VIF
# 0                           age 5.45
# 1          number_of_dependants 2.73
# 2      years_at_current_address 3.41
# 3                       zipcode 3.77
# 4            loan_tenure_months 5.98
# 5   bank_balance_at_application 1.80
# 6       number_of_open_accounts 4.32
# 7     number_of_closed_accounts 2.35
# 8                 enquiry_count 6.37
# 9      credit_utilization_ratio 2.92
# 10               loan_to_income 4.53
# 11            dilenquency_ratio 1.95
# 12      avg_dpd_per_delinquency 2.93

# %%
def calculate_woe_iv(df, feature, target):
    grouped = df.groupby(feature)[target].agg(['count','sum'])
    grouped = grouped.rename(columns={'count': 'total', 'sum': 'good'})
    grouped['bad']=grouped['total']-grouped['good']
    
    total_good = grouped['good'].sum()
    total_bad = grouped['bad'].sum()
    
    grouped['good_pct'] = grouped['good'] / total_good
    grouped['bad_pct'] = grouped['bad'] / total_bad
    grouped['woe'] = np.log(grouped['good_pct']/ grouped['bad_pct'])
    grouped['iv'] = (grouped['good_pct'] -grouped['bad_pct'])*grouped['woe']
    
    grouped['woe'] = grouped['woe'].replace([np.inf, -np.inf], 0)
    grouped['iv'] = grouped['iv'].replace([np.inf, -np.inf], 0)
    
    total_iv = grouped['iv'].sum()
    
    return grouped, total_iv

grouped, total_iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), 'loan_purpose', 'default')
grouped
# Out:
#               total  good    bad  good_pct  bad_pct   woe   iv
# loan_purpose
# Auto           7437   314   7123      0.10     0.21 -0.75 0.08
# Education      5626   546   5080      0.17     0.15  0.14 0.00
# Home          11271  1744   9527      0.55     0.28  0.68 0.18
# Personal      13153   585  12568      0.18     0.37 -0.69 0.13

# %%
X_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37487 entries, 27434 to 15795
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   age                          37487 non-null  float64
#  1   gender                       37487 non-null  object
#  2   marital_status               37487 non-null  object
#  3   employment_status            37487 non-null  object
#  4   number_of_dependants         37487 non-null  float64
#  5   residence_type               37487 non-null  object
#  6   years_at_current_address     37487 non-null  float64
#  7   city                         37487 non-null  object
#  8   state                        37487 non-null  object
#  9   zipcode                      37487 non-null  float64
#  10  loan_purpose                 37487 non-null  object
#  11  loan_type                    37487 non-null  object
#  12  loan_tenure_months           37487 non-null  float64
#  13  bank_balance_at_application  37487 non-null  float64
#  14  number_of_open_accounts      37487 non-null  float64
#  15  number_of_closed_accounts    37487 non-null  float64
#  16  enquiry_count                37487 non-null  float64
#  17  credit_utilization_ratio     37487 non-null  float64
#  18  loan_to_income               37487 non-null  float64
#  19  dilenquency_ratio            37487 non-null  float64
#  20  avg_dpd_per_delinquency      37487 non-null  float64
# dtypes: float64(13), object(8)
# memory usage: 6.3+ MB

# %%
iv_values = {}

for feature in X_train_1.columns:
    if X_train_1[feature].dtype == 'object':
        _, iv = calculate_woe_iv(pd.concat([X_train_1, y_train],axis=1), feature, 'default' )
    else:
        X_binned = pd.cut(X_train_1[feature], bins=10, labels=False)
        _, iv = calculate_woe_iv(pd.concat([X_binned, y_train],axis=1), feature, 'default' )
    iv_values[feature] = iv
        
iv_values
# Out:
# {'age': np.float64(0.07592687127752061),
#  'gender': np.float64(0.000482276463421216),
#  'marital_status': np.float64(0.002196681370832318),
#  'employment_status': np.float64(0.002447818101774487),
#  'number_of_dependants': np.float64(0.00364589452118596),
#  'residence_type': np.float64(0.2594019617563985),
#  'years_at_current_address': np.float64(0.001042536380353028),
#  'city': np.float64(0.000817870465334103),
#  'state': np.float64(0.0007881984519711978),
#  'zipcode': np.float64(0.0007436024782513755),
#  'loan_purpose': np.float64(0.39377543144164784),
#  'loan_type': np.float64(0.17304705897793143),
#  'loan_tenure_months': np.float64(0.23450610202970526),
#  'bank_balance_at_application': np.float64(0.004242001247914226),
#  'number_of_open_accounts': np.float64(0.07324250836253295),
#  'number_of_closed_accounts': np.float64(0.00026280824021760536),
#  'enquiry_count': np.float64(0.005484982638303533),
#  'credit_utilization_ratio': np.float64(2.4228228499400095),
#  'loan_to_income': np.float64(0.4915664145044282),
#  'dilenquency_ratio': np.float64(0.67818280349235),
#  'avg_dpd_per_delinquency': np.float64(0.4210029044696208)}

# %%
# select features that has IV > 0.02
selected_features_iv = [feature for feature, iv in iv_values.items() if iv > 0.02]
selected_features_iv
# Out:
# ['age',
#  'residence_type',
#  'loan_purpose',
#  'loan_type',
#  'loan_tenure_months',
#  'number_of_open_accounts',
#  'credit_utilization_ratio',
#  'loan_to_income',
#  'dilenquency_ratio',
#  'avg_dpd_per_delinquency']

# %%
X_train_reduced = X_train_1[selected_features_iv]
X_test_reduced = X_test[selected_features_iv]

# %%
X_train_encoded = pd.get_dummies(X_train_reduced, drop_first=True)
X_train_encoded.head(3)
# Out:
#        age  loan_tenure_months  number_of_open_accounts  \
# 27434 0.52                0.34                     1.00
# 13400 0.21                0.51                     0.67
# 883   0.62                0.25                     0.33
#
#        credit_utilization_ratio  loan_to_income  dilenquency_ratio  \
# 27434                      0.60            0.61               0.07
# 13400                      0.93            0.18               0.03
# 883                        0.84            0.08               0.17
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 27434                     0.55                  True                  False
# 13400                     0.42                  True                  False
# 883                       0.56                 False                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 27434                   False               True                  False
# 13400                   False              False                  False
# 883                     False              False                   True
#
#        loan_type_Unsecured
# 27434                False
# 13400                False
# 883                   True

# %%
X_test_encoded = pd.get_dummies(X_test_reduced, drop_first=True)
X_test_encoded.head(3)
# Out:
#        age  loan_tenure_months  number_of_open_accounts  \
# 33553 0.35                0.53                     0.33
# 9427  0.29                0.62                     1.00
# 199   0.19                0.62                     1.00
#
#        credit_utilization_ratio  loan_to_income  dilenquency_ratio  \
# 33553                      0.12            0.26               0.04
# 9427                       0.86            0.69               0.00
# 199                        0.73            0.63               0.00
#
#        avg_dpd_per_delinquency  residence_type_Owned  residence_type_Rented  \
# 33553                     0.90                  True                  False
# 9427                      0.00                  True                  False
# 199                       0.00                  True                  False
#
#        loan_purpose_Education  loan_purpose_Home  loan_purpose_Personal  \
# 33553                    True              False                  False
# 9427                    False               True                  False
# 199                     False               True                  False
#
#        loan_type_Unsecured
# 33553                False
# 9427                 False
# 199                  False

# %% [markdown]
# # Model Prediction

# %% [markdown]
# ## using logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
model_lr = LogisticRegression()
model_lr.fit(X_train_encoded,y_train)
y_pred_lr = model_lr.predict(X_test_encoded)
report = classification_report(y_test,y_pred_lr)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11390
#            1       0.84      0.70      0.76      1108
#
#     accuracy                           0.96     12498
#    macro avg       0.90      0.84      0.87     12498
# weighted avg       0.96      0.96      0.96     12498

# %% [markdown]
# ## Feature importance

# %%
feature_importance = model_lr.coef_[0]
feature_importance
# Out:
# array([-0.51042971,  0.55347223,  0.61812067, 12.70735969, 10.58866847,
#         9.37833808,  2.02221631, -1.4675894 ,  1.53746473,  0.99361687,
#        -1.26100718,  0.67067752,  0.67067752])

# %%
coef_df = pd.DataFrame(feature_importance,index =X_train_encoded.columns,columns = ['Coeficient'])
coef_df = coef_df.sort_values(by = 'Coeficient',ascending = True)

plt.figure(figsize= (8,5))
sns.barplot(x = coef_df.index,y = coef_df['Coeficient'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ## using xgboost classifier

# %%
from xgboost import XGBClassifier

model_xgb = XGBClassifier()
model_xgb.fit(X_train_encoded, y_train)

y_pred_xgb = model_xgb.predict(X_test_encoded)
report = classification_report(y_test, y_pred_xgb)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     11390
#            1       0.82      0.74      0.78      1108
#
#     accuracy                           0.96     12498
#    macro avg       0.90      0.86      0.88     12498
# weighted avg       0.96      0.96      0.96     12498

# %%
from sklearn.model_selection import RandomizedSearchCV
params = {'C' : [1,2,5,10,15,100],
         'solver' : ['lbfgs', 'saga', 'liblinear', 'newton-cg']
         }
log_reg = LogisticRegression(max_iter = 10000)
random_search = RandomizedSearchCV(estimator = log_reg,
                param_distributions=params,
                n_iter = 50,
                scoring = 'f1',
                cv = 5,
                n_jobs=-1,
                verbose = 2,
                random_state=42                   

        
)
random_search.fit(X_train_encoded,y_train)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# C:\Users\Yash\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 24 is smaller than n_iter=50. Running 24 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(max_iter=10000),
#                    n_iter=50, n_jobs=-1,
#                    param_distributions={'C': [1, 2, 5, 10, 15, 100],
#                                         'solver': ['lbfgs', 'saga', 'liblinear',
#                                                    'newton-cg']},
#                    random_state=42, scoring='f1', verbose=2)

# %%
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Best Parameters: {'solver': 'saga', 'C': 100}
# Best Score: 0.7625519536226248
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     11390
#            1       0.83      0.71      0.77      1108
#
#     accuracy                           0.96     12498
#    macro avg       0.90      0.85      0.87     12498
# weighted avg       0.96      0.96      0.96     12498

# %%
from scipy.stats import uniform, randint
from sklearn.model_selection import RandomizedSearchCV

# Define parameter distribution for RandomizedSearchCV
param_dist = {
    'n_estimators': [100, 150, 200, 250, 300],
    'max_depth': [3, 4, 5, 6, 7, 8, 9, 10],
    'learning_rate': [0.01, 0.03, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3],
    'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
    'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
    'scale_pos_weight': [1, 2, 3, 5, 7, 10],
    'reg_alpha': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0],  # L1 regularization term
    'reg_lambda': [0.01, 0.1, 0.5, 1.0, 5.0, 10.0]  # L2 regularization term
}

xgb = XGBClassifier()

random_search = RandomizedSearchCV(estimator=xgb, param_distributions=param_dist, n_iter=100,
                                   scoring='f1', cv=3, verbose=1, n_jobs=-1, random_state=42)

random_search.fit(X_train_encoded, y_train)

# Print the best parameters and best score
print(f"Best Parameters: {random_search.best_params_}")
print(f"Best Score: {random_search.best_score_}")

best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test_encoded)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# C:\Users\Yash\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py:528: FitFailedWarning:
# 1 fits failed out of a total of 300.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Yash\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 729, in inner_f
#     return func(**kwargs)
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py", line 1664, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py", line 628, in _wrap_evaluation_matrices
#     train_dmatrix = create_dmatrix(
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py", line 1137, in _create_dmatrix
#     return QuantileDMatrix(
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 729, in inner_f
#     return func(**kwargs)
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 1614, in __init__
#     self._init(
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 1678, in _init
#     it.reraise()
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 572, in reraise
#     raise exc  # pylint: disable=raising-bad-type
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 553, in _handle_exception
#     return fn()
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 640, in <lambda>
#     return self._handle_exception(lambda: int(self.next(input_data)), 0)
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py", line 1654, in next
#     input_data(**self.kwargs)
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 729, in inner_f
#     return func(**kwargs)
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 628, in input_data
#     dispatch_proxy_set_data(self.proxy, new, cat_codes)
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py", line 1749, in dispatch_proxy_set_data
#     proxy._ref_data_from_columnar(data)  # pylint: disable=W0212
#   File "C:\Users\Yash\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\core.py", line 1467, in _ref_data_from_columnar
#     _LIB.XGProxyDMatrixSetDataColumnar(self.handle, data.array_interface())
# OSError: exception: access violation reading 0x0000000000000030
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\Yash\AppData\Roaming\Python\Python310\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [0.78407399 0.76439374        nan 0.75719115 0.7814303  0.76494384
#  0.76969045 0.58310979 0.76523479 0.73629694 0.7632802  0.77539988
#  0.76552821 0.78960802 0.77626631 0.76807905 0.7647063  0.76294524
#  0.76078192 0.77273216 0.7705935  0.76462231 0.78252593 0.76683313
#  0.78348734 0.77796617 0.76593327 0.76735686 0.778312   0.76538608
#  0.78328675 0.77394501 0.77370199 0.74872181 0.76933629 0.76495682
#  0.78000412 0.78447244 0.76783087 0.77555315 0.74205428 0.75407924
#  0.77996346 0.68748006 0.78223766 0.76254569 0.74797372 0.77550482
#  0.76588685 0.76978771 0.77342762 0.7631615  0.77765717 0.758845
#  0.77409892 0.77934111 0.7574008  0.75534738 0.7189384  0.77340012
#  0.7700295  0.76251894 0.77825549 0.79078124 0.68789364 0.77913976
#  0.76805838 0.75565988 0.77785391 0.77239972 0.76337816 0.7609866
#  0.76568158 0.77754445 0.76526368 0.77154089 0.77272927 0.77126992
#  0.75605977 0.78023118 0.7776591  0.74215072 0.7748089  0.78575631
#  0.78323084 0.78187381 0.76541272 0.76760177 0.76214558 0.77103194
#  0.76853903 0.77255991 0.76684859 0.7761112  0.76648578 0.76458541
#  0.74365268 0.71829424 0.70341454 0.76650052]
#   warnings.warn(
# Best Parameters: {'subsample': 0.8, 'scale_pos_weight': 2, 'reg_lambda': 1.0, 'reg_alpha': 5.0, 'n_estimators': 100, 'max_depth': 3, 'learning_rate': 0.2, 'colsample_bytree': 0.9}
# Best Score: 0.790781241305533
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     11390
#            1       0.78      0.82      0.80      1108
#
#     accuracy                           0.96     12498
#    macro avg       0.88      0.90      0.89     12498
# weighted avg       0.96      0.96      0.96     12498

# %% [markdown]
# ## Attempt 3
# Logistic Regression
# Handle Class Imbalance Using SMOTE Tomek
# Parameter tunning using optuna

# %%
from imblearn.combine import SMOTETomek

smt = SMOTETomek(random_state=42)
X_train_smt, y_train_smt = smt.fit_resample(X_train_encoded, y_train)
y_train_smt.value_counts()
# Out:
# default
# 0    34229
# 1    34229
# Name: count, dtype: int64

# %%
best_model = LogisticRegression()
best_model.fit(X_train_smt, y_train_smt)

y_pred = best_model.predict(X_test_encoded)
report = classification_report(y_test, y_pred)
print(report) #recall is more important in this case hence we focus on higher recall
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96     11390
#            1       0.57      0.94      0.71      1108
#
#     accuracy                           0.93     12498
#    macro avg       0.78      0.94      0.83     12498
# weighted avg       0.96      0.93      0.94     12498

# %%
from sklearn.metrics import roc_curve
probablities = best_model.predict_proba(X_test_encoded)[:,1]
fpr,tpr,threshold = roc_curve(y_test,probablities)

# %% [markdown]
# from sklearn.metrics import auc
# area = auc(fpr,tpr)
# print(area)

# %% [markdown]
# ## roc_curve

# %%
plt.figure(figsize = (6,5))
plt.plot(fpr,tpr)
plt.plot([0,1],[0,1])
plt.xlim([0.0,1.0])
plt.ylim([0.0,1.05])
plt.show()

# %%
from joblib import dump 
model_data = {'model':best_model,
             'scaler' : scaler,
             'features' : X_train_encoded.columnns,
             'cols_to_scale':cols_to_scale}
dump(model_data, 'artifacts/model_data.joblib')
# Out:
# Index(['age', 'loan_tenure_months', 'number_of_open_accounts',
#        'credit_utilization_ratio', 'loan_to_income', 'dilenquency_ratio',
#        'avg_dpd_per_delinquency', 'residence_type_Owned',
#        'residence_type_Rented', 'loan_purpose_Education', 'loan_purpose_Home',
#        'loan_purpose_Personal', 'loan_type_Unsecured'],
#       dtype='object')
